# %%
from qiskit import QuantumCircuit
qc=QuantumCircuit(2)
qc.x(0)
qc.draw('mpl')

# %%
from qiskit import QuantumCircuit
qc=QuantumCircuit(2)
qc.h(0)
qc.draw('mpl')

# %%
from qiskit import QuantumCircuit
qc=QuantumCircuit(2)
qc.z(0)
qc.draw('mpl')

# %%
from qiskit import QuantumCircuit
qc=QuantumCircuit(2)
qc.cx(0,1)
qc.draw('mpl')

# %%
from qiskit import QuantumCircuit
qc=QuantumCircuit(2)
qc.h(0)
qc.cx(0,1)
qc.draw('mpl')
